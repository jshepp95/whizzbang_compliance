# %%
from PIL import Image
import os
import random
import numpy as np
import utils
import cv2
import matplotlib.pyplot as plt

# %%
# Constants
REFERENCE_LOZENGE_SIZE = (331, 364)  # Our known good size for the reference image
REFERENCE_IMAGE_PATH = "data/imgs/raw/img_001.jpg"
output_dir = "data/imgs/synth"
os.makedirs(output_dir, exist_ok=True)

# Load and get dimensions of reference image
reference_img = cv2.imread(REFERENCE_IMAGE_PATH)
ref_height, ref_width = reference_img.shape[:2]
print(f"Reference image size: {ref_width}x{ref_height}")

# Calculate the reference ratio (how much of the reference image width the lozenge should occupy)
REFERENCE_WIDTH_RATIO = REFERENCE_LOZENGE_SIZE[0] / ref_width
print(f"Reference width ratio: {REFERENCE_WIDTH_RATIO:.3f}")

# Get list of lozenge variations
lozenge_dir = "data/brand_assets/processed/nectar_lozenge"
lozenge_files = [f for f in os.listdir(lozenge_dir) if f.endswith(('.png', '.PNG'))]
if not lozenge_files:
    raise ValueError("No lozenge images found in the specified directory")

# Get list of background images
background_files = [f for f in os.listdir("data/imgs/raw") if f.endswith('.jpg')][:]
padding = 20

for bg_file in background_files:
    background_path = os.path.join("data/imgs/raw", bg_file)
    background = cv2.imread(background_path)
    
    # Randomly select a lozenge for this iteration
    selected_lozenge_file = random.choice(lozenge_files)
    lozenge_path = os.path.join(lozenge_dir, selected_lozenge_file)
    lozenge = cv2.imread(lozenge_path, cv2.IMREAD_UNCHANGED)
    
    # Get background dimensions
    bg_height, bg_width = background.shape[:2]
    
    # Calculate the scaled size maintaining the same relative proportion as the reference image
    scaled_width = int(bg_width * REFERENCE_WIDTH_RATIO)
    aspect_ratio = REFERENCE_LOZENGE_SIZE[1] / REFERENCE_LOZENGE_SIZE[0]  # height/width
    scaled_height = int(scaled_width * aspect_ratio)
    
    # Scale lozenge for this specific background
    scaled_lozenge_dynamic = utils.scale_img(lozenge, (scaled_width, scaled_height))
    
    print(f"\nProcessing {bg_file}")
    print(f"Using lozenge: {selected_lozenge_file}")
    print(f"Background size: {bg_width}x{bg_height}")
    print(f"Scaled lozenge size: {scaled_lozenge_dynamic.shape}")

    # Get dimensions for placement
    loz_height, loz_width = scaled_lozenge_dynamic.shape[:2]

    # Skip images that are too small
    if bg_width < loz_width + 2*padding or bg_height < loz_height + 2*padding:
        print(f"Skipping {bg_file} - image too small for lozenge")
        continue

    regions = {
        'upper_left': {
            'x_range': (padding, min(bg_width//2 - loz_width - padding, bg_width - loz_width - padding)),
            'y_range': (padding, min(bg_height//2 - loz_height - padding, bg_height - loz_height - padding))
        },
        'center': {
            'x_range': (bg_width//4, min(3*bg_width//4 - loz_width - padding, bg_width - loz_width - padding)),
            'y_range': (bg_height//4, min(3*bg_height//4 - loz_height - padding, bg_height - loz_height - padding))
        },
        'lower_left': {
            'x_range': (padding, min(bg_width//2 - loz_width - padding, bg_width - loz_width - padding)),
            'y_range': (bg_height//2, min(bg_height - loz_height - padding, bg_height - loz_height - padding))
        }
    }

    valid_regions = {}
    for name, region in regions.items():
        x_start, x_end = region['x_range']
        y_start, y_end = region['y_range']
        
        if x_end > x_start and y_end > y_start:
            valid_regions[name] = region

    if not valid_regions:
        print(f"Skipping {bg_file} - no valid regions found")
        continue

    chosen_region = random.choice(list(valid_regions.keys()))
    region = valid_regions[chosen_region]

    x_offset = random.randint(*region['x_range'])
    y_offset = random.randint(*region['y_range'])

    print(f">> PLACING @{chosen_region} REGION, POSITION ({x_offset}, {y_offset})")

    # BLEND
    loz = scaled_lozenge_dynamic.astype(np.float32) / 255.0
    alpha_channel = loz[:, :, 3]
    rgb_loz = loz[:, :, :3]

    # Extract ROI with correct dimensions
    roi = background[y_offset:y_offset+loz_height, x_offset:x_offset+loz_width].astype(np.float32) / 255.0

    for c in range(3):
        roi[:, :, c] = roi[:, :, c] * (1 - alpha_channel) + rgb_loz[:, :, c] * alpha_channel

    roi = (roi * 255).astype(np.uint8)
    background[y_offset:y_offset+loz_height, x_offset:x_offset+loz_width] = roi

    # Save with original filename plus suffix
    output_filename = f"synth_{bg_file}"
    output_path = os.path.join(output_dir, output_filename)
    cv2.imwrite(output_path, background)
# Out:
# Reference image size: 1418x1417
# Reference width ratio: 0.233
#
# Processing img_158.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (20, 1433)
#
# Processing img_023.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1208x1208
# Scaled lozenge size: (309, 272, 4)
# >> PLACING @lower_left REGION, POSITION (260, 718)
#
# Processing img_026.jpg
# Using lozenge: Artboard 96.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (492, 277)
#
# Processing img_202.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 4500x4500
# Scaled lozenge size: (1154, 1046, 4)
# >> PLACING @lower_left REGION, POSITION (167, 2793)
#
# Processing img_020.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (70, 739)
#
# Processing img_009.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 300x600
# Scaled lozenge size: (76, 68, 4)
# >> PLACING @lower_left REGION, POSITION (28, 343)
#
# Processing img_194.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (72, 1059)
#
# Processing img_132.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (384, 395)
#
# Processing img_155.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (190, 1384)
#
# Processing img_195.jpg
# Using lozenge: Artboard 5_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (252, 722)
#
# Processing img_111.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (48, 124)
#
# Processing img_134.jpg
# Using lozenge: Artboard 83.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (116, 1326)
#
# Processing img_197.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (57, 564)
#
# Processing img_128.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (91, 119)
#
# Processing img_039.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (49, 724)
#
# Processing img_165.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (296, 507)
#
# Processing img_157.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (436, 459)
#
# Processing img_173.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (80, 299)
#
# Processing img_003.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (31, 180)
#
# Processing img_179.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (486, 821)
#
# Processing img_053.jpg
# Using lozenge: Artboard 7_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (132, 235)
#
# Processing img_108.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (108, 45)
#
# Processing img_085.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (422, 466)
#
# Processing img_149.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (81, 42)
#
# Processing img_034.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1208x1208
# Scaled lozenge size: (309, 274, 4)
# >> PLACING @upper_left REGION, POSITION (238, 36)
#
# Processing img_066.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (463, 325)
#
# Processing img_027.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (125, 49)
#
# Processing img_189.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (539, 348)
#
# Processing img_192.jpg
# Using lozenge: Artboard 96.png
# Background size: 1081x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (327, 618)
#
# Processing img_056.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (123, 149)
#
# Processing img_048.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (285, 365)
#
# Processing img_097.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (493, 344)
#
# Processing img_088.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (283, 834)
#
# Processing img_125.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 2048x2048
# Scaled lozenge size: (525, 466, 4)
# >> PLACING @center REGION, POSITION (709, 906)
#
# Processing img_170.jpg
# Using lozenge: Artboard 96.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (159, 115)
#
# Processing img_139.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (148, 1073)
#
# Processing img_137.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (168, 324)
#
# Processing img_196.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (43, 656)
#
# Processing img_050.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (167, 41)
#
# Processing img_028.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (48, 703)
#
# Processing img_114.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (67, 1321)
#
# Processing img_103.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (271, 390)
#
# Processing img_054.jpg
# Using lozenge: Artboard 96.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (56, 175)
#
# Processing img_198.jpg
# Using lozenge: Artboard 5_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (76, 60)
#
# Processing img_116.jpg
# Using lozenge: Artboard 10_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (262, 23)
#
# Processing img_044.jpg
# Using lozenge: Artboard 10_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (166, 533)
#
# Processing img_001.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1418x1417
# Scaled lozenge size: (364, 325, 4)
# >> PLACING @upper_left REGION, POSITION (315, 292)
#
# Processing img_201.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (127, 632)
#
# Processing img_151.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (230, 504)
#
# Processing img_067.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (211, 1552)
#
# Processing img_203.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (518, 875)
#
# Processing img_033.jpg
# Using lozenge: Artboard 7_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (103, 223)
#
# Processing img_184.jpg
# Using lozenge: Artboard 10_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (183, 126)
#
# Processing img_042.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (179, 280)
#
# Processing img_013.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (529, 463)
#
# Processing img_105.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 244, 4)
# >> PLACING @upper_left REGION, POSITION (66, 34)
#
# Processing img_140.jpg
# Using lozenge: Artboard 7_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (80, 1327)
#
# Processing img_115.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (347, 379)
#
# Processing img_032.jpg
# Using lozenge: Artboard 7_1.png
# Background size: 1200x1500
# Scaled lozenge size: (307, 279, 4)
# >> PLACING @center REGION, POSITION (468, 593)
#
# Processing img_024.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (358, 410)
#
# Processing img_035.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (51, 196)
#
# Processing img_112.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (440, 489)
#
# Processing img_076.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (180, 1053)
#
# Processing img_059.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (143, 311)
#
# Processing img_129.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (26, 83)
#
# Processing img_065.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (501, 621)
#
# Processing img_089.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (127, 70)
#
# Processing img_008.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (415, 731)
#
# Processing img_006.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (112, 57)
#
# Processing img_025.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (225, 52)
#
# Processing img_007.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (235, 101)
#
# Processing img_057.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (126, 393)
#
# Processing img_161.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (295, 299)
#
# Processing img_190.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (354, 379)
#
# Processing img_150.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (100, 753)
#
# Processing img_049.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (492, 381)
#
# Processing img_148.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (400, 369)
#
# Processing img_200.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (226, 703)
#
# Processing img_087.jpg
# Using lozenge: Artboard 83.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (289, 400)
#
# Processing img_101.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (25, 614)
#
# Processing img_070.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (145, 104)
#
# Processing img_061.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (204, 167)
#
# Processing img_133.jpg
# Using lozenge: Artboard 10_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (217, 617)
#
# Processing img_038.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (366, 291)
#
# Processing img_086.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (69, 204)
#
# Processing img_127.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (349, 874)
#
# Processing img_171.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (193, 1126)
#
# Processing img_098.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (363, 591)
#
# Processing img_092.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 244, 4)
# >> PLACING @lower_left REGION, POSITION (148, 682)
#
# Processing img_119.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (409, 912)
#
# Processing img_136.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (494, 274)
#
# Processing img_017.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 244, 4)
# >> PLACING @center REGION, POSITION (451, 392)
#
# Processing img_145.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (358, 1012)
#
# Processing img_060.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (73, 123)
#
# Processing img_177.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (151, 120)
#
# Processing img_168.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1084x1089
# Scaled lozenge size: (278, 248, 4)
# >> PLACING @center REGION, POSITION (511, 403)
#
# Processing img_036.jpg
# Using lozenge: Artboard 80.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (314, 446)
#
# Processing img_144.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (123, 145)
#
# Processing img_102.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (497, 493)
#
# Processing img_117.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (270, 566)
#
# Processing img_185.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (523, 399)
#
# Processing img_163.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (539, 1136)
#
# Processing img_146.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 244, 4)
# >> PLACING @center REGION, POSITION (307, 489)
#
# Processing img_143.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (83, 26)
#
# Processing img_031.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (249, 174)
#
# Processing img_022.jpg
# Using lozenge: Artboard 82.png
# Background size: 1208x1208
# Scaled lozenge size: (309, 276, 4)
# >> PLACING @lower_left REGION, POSITION (209, 612)
#
# Processing img_029.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (106, 128)
#
# Processing img_120.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (91, 96)
#
# Processing img_199.jpg
# Using lozenge: Artboard 83.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (271, 433)
#
# Processing img_142.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1200x1200
# Scaled lozenge size: (307, 274, 4)
# >> PLACING @lower_left REGION, POSITION (86, 626)
#
# Processing img_095.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (410, 441)
#
# Processing img_193.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (99, 524)
#
# Processing img_074.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (179, 669)
#
# Processing img_104.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (69, 46)
#
# Processing img_164.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (70, 184)
#
# Processing img_099.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (347, 503)
#
# Processing img_180.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (202, 203)
#
# Processing img_107.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (162, 639)
#
# Processing img_176.jpg
# Using lozenge: Artboard 7_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (537, 1104)
#
# Processing img_122.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (283, 438)
#
# Processing img_021.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (473, 380)
#
# Processing img_052.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (26, 589)
#
# Processing img_079.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (189, 1486)
#
# Processing img_075.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (198, 1623)
#
# Processing img_096.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (256, 1256)
#
# Processing img_037.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (171, 553)
#
# Processing img_121.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (395, 651)
#
# Processing img_100.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (254, 1605)
#
# Processing img_051.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1920x1920
# Scaled lozenge size: (491, 439, 4)
# >> PLACING @center REGION, POSITION (666, 551)
#
# Processing img_063.jpg
# Using lozenge: Artboard 83.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (475, 367)
#
# Processing img_110.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (166, 1405)
#
# Processing img_188.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (159, 752)
#
# Processing img_124.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (143, 1168)
#
# Processing img_091.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (230, 400)
#
# Processing img_166.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (394, 361)
#
# Processing img_093.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (168, 750)
#
# Processing img_084.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 244, 4)
# >> PLACING @lower_left REGION, POSITION (247, 1083)
#
# Processing img_071.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (317, 273)
#
# Processing img_068.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (143, 1501)
#
# Processing img_106.jpg
# Using lozenge: Artboard 96.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (414, 578)
#
# Processing img_131.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (465, 382)
#
# Processing img_062.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (124, 1287)
#
# Processing img_064.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (185, 118)
#
# Processing img_126.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (321, 809)
#
# Processing img_043.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (87, 731)
#
# Processing img_154.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (217, 758)
#
# Processing img_159.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (103, 566)
#
# Processing img_078.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (182, 127)
#
# Processing img_015.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (159, 62)
#
# Processing img_080.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (121, 1109)
#
# Processing img_191.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (45, 659)
#
# Processing img_183.jpg
# Using lozenge: Artboard 83.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (186, 207)
#
# Processing img_152.jpg
# Using lozenge: Artboard 9_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 244, 4)
# >> PLACING @center REGION, POSITION (467, 489)
#
# Processing img_123.jpg
# Using lozenge: Artboard 11_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (481, 405)
#
# Processing img_046.jpg
# Using lozenge: Artboard 92.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (517, 578)
#
# Processing img_094.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (273, 379)
#
# Processing img_113.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (199, 644)
#
# Processing img_182.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (488, 843)
#
# Processing img_181.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (89, 200)
#
# Processing img_187.jpg
# Using lozenge: Artboard 5_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (340, 371)
#
# Processing img_118.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (439, 326)
#
# Processing img_109.jpg
# Using lozenge: Artboard 80.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (157, 174)
#
# Processing img_082.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (283, 1022)
#
# Processing img_083.jpg
# Using lozenge: Artboard 80.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (99, 210)
#
# Processing img_090.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @lower_left REGION, POSITION (121, 1194)
#
# Processing img_130.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (32, 1180)
#
# Processing img_047.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (237, 309)
#
# Processing img_147.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (424, 275)
#
# Processing img_040.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (130, 53)
#
# Processing img_178.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1084
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (337, 359)
#
# Processing img_004.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (420, 407)
#
# Processing img_153.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (106, 148)
#
# Processing img_174.jpg
# Using lozenge: Artboard 16_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (128, 60)
#
# Processing img_169.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (257, 207)
#
# Processing img_175.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (268, 698)
#
# Processing img_010.jpg
# Using lozenge: Artboard 95.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (343, 371)
#
# Processing img_005.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @lower_left REGION, POSITION (106, 1437)
#
# Processing img_072.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @upper_left REGION, POSITION (171, 210)
#
# Processing img_014.jpg
# Using lozenge: Artboard 5_1.png
# Background size: 300x600
# Scaled lozenge size: (76, 68, 4)
# >> PLACING @lower_left REGION, POSITION (21, 357)
#
# Processing img_081.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (327, 626)
#
# Processing img_069.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (420, 648)
#
# Processing img_058.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (257, 465)
#
# Processing img_138.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (362, 1031)
#
# Processing img_141.jpg
# Using lozenge: Artboard 96.png
# Background size: 1200x1200
# Scaled lozenge size: (307, 275, 4)
# >> PLACING @upper_left REGION, POSITION (286, 168)
#
# Processing img_167.jpg
# Using lozenge: Artboard 6_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @upper_left REGION, POSITION (181, 302)
#
# Processing img_045.jpg
# Using lozenge: Artboard 8_1.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 251, 4)
# >> PLACING @center REGION, POSITION (357, 618)
#
# Processing img_077.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (169, 208)
#
# Processing img_162.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (269, 546)
#
# Processing img_160.jpg
# Using lozenge: Artboard 12_1.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (127, 241)
#
# Processing img_073.jpg
# Using lozenge: Artboard 94.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (175, 131)
#
# Processing img_018.jpg
# Using lozenge: Artboard 2_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (172, 173)
#
# Processing img_041.jpg
# Using lozenge: Artboard 13_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (134, 680)
#
# Processing img_172.jpg
# Using lozenge: Artboard 83.png
# Background size: 1080x1920
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (324, 1008)
#
# Processing img_011.jpg
# Using lozenge: Artboard 5_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (209, 126)
#
# Processing img_019.jpg
# Using lozenge: Artboard 96.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (210, 32)
#
# Processing img_156.jpg
# Using lozenge: Artboard 14_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @lower_left REGION, POSITION (118, 724)
#
# Processing img_002.jpg
# Using lozenge: Artboard 3_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @center REGION, POSITION (453, 294)
#
# Processing img_055.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @center REGION, POSITION (498, 325)
#
# Processing img_016.jpg
# Using lozenge: Artboard 95.png
# Background size: 300x250
# Scaled lozenge size: (76, 68, 4)
# >> PLACING @center REGION, POSITION (108, 83)
#
# Processing img_186.jpg
# Using lozenge: Artboard 15_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 246, 4)
# >> PLACING @lower_left REGION, POSITION (206, 669)
#
# Processing img_012.jpg
# Using lozenge: Artboard 82.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @center REGION, POSITION (313, 347)
#
# Processing img_135.jpg
# Using lozenge: Artboard 4_1.png
# Background size: 1080x1080
# Scaled lozenge size: (277, 247, 4)
# >> PLACING @upper_left REGION, POSITION (173, 126)
#
# Processing img_030.jpg
# Using lozenge: Artboard 93.png
# Background size: 1080x1350
# Scaled lozenge size: (277, 248, 4)
# >> PLACING @upper_left REGION, POSITION (190, 158)

# %%
REFERENCE_LOZENGE_SIZE = (331, 364)  # Our known good size for the reference image
REFERENCE_IMAGE_PATH = "archive/data/imgs/raw/img_001.jpg"
output_dir = "archive/data/imgs/synth__"
os.makedirs(output_dir, exist_ok=True)

# Load and get dimensions of reference image
reference_img = cv2.imread(REFERENCE_IMAGE_PATH)
ref_height, ref_width = reference_img.shape[:2]
print(f"Reference image size: {ref_width}x{ref_height}")

# Calculate the reference ratio (how much of the reference image width the lozenge should occupy)
REFERENCE_WIDTH_RATIO = REFERENCE_LOZENGE_SIZE[0] / ref_width
print(f"Reference width ratio: {REFERENCE_WIDTH_RATIO:.3f}")

# Get list of lozenge variations
lozenge_dir = "archive/data/brand_assets/processed/nectar_lozenge"
lozenge_files = [f for f in os.listdir(lozenge_dir) if f.endswith(('.png', '.PNG'))]
if not lozenge_files:
    raise ValueError("No lozenge images found in the specified directory")
# Out:
# Reference image size: 1418x1417
# Reference width ratio: 0.233

# %%
import cv2
import numpy as np
import os

# Constants
FPS = 30
DURATION = 3  # seconds
TOTAL_FRAMES = FPS * DURATION

# Paths
lozenge_dir = "archive/data/brand_assets/processed/nectar_lozenge"
reference_img_path = "archive/data/imgs/raw/img_001.jpg"  # Just for dimensions
output_path = "archive/data/imgs/synth__/lozenge_animation.mp4"

# Get reference dimensions from original image
reference_img = cv2.imread(reference_img_path)
bg_height, bg_width = reference_img.shape[:2]

# Create white background of same size
background = np.full((bg_height, bg_width, 3), 255, dtype=np.uint8)  # White background

# Rest of your code stays the same
lozenge_files = [f for f in os.listdir(lozenge_dir) if f.endswith(('.png', '.PNG'))]
selected_lozenge_file = random.choice(lozenge_files)
lozenge = cv2.imread(os.path.join(lozenge_dir, selected_lozenge_file), cv2.IMREAD_UNCHANGED)

# Scale lozenge
REFERENCE_LOZENGE_SIZE = (331, 364)
scaled_lozenge = cv2.resize(lozenge, REFERENCE_LOZENGE_SIZE)
loz_height, loz_width = scaled_lozenge.shape[:2]

# Setup video writer
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_path, fourcc, FPS, (bg_width, bg_height))

# Calculate movement
start_x = (bg_width - loz_width) // 2  # Center
end_x = bg_width - loz_width - 20      # Right edge with padding
total_movement = end_x - start_x

for frame_num in range(TOTAL_FRAMES):
    # Create fresh white background for each frame
    frame = background.copy()
    
    progress = frame_num / TOTAL_FRAMES
    eased_progress = (1 - np.cos(progress * np.pi)) / 2
    current_x = int(start_x + (total_movement * eased_progress))
    
    y_offset = (bg_height - loz_height) // 2
    
    # Blend lozenge
    loz = scaled_lozenge.astype(np.float32) / 255.0
    alpha_channel = loz[:, :, 3]
    rgb_loz = loz[:, :, :3]
    
    roi = frame[y_offset:y_offset+loz_height, 
                current_x:current_x+loz_width].astype(np.float32) / 255.0
    
    for c in range(3):
        roi[:, :, c] = roi[:, :, c] * (1 - alpha_channel) + rgb_loz[:, :, c] * alpha_channel
    
    roi = (roi * 255).astype(np.uint8)
    frame[y_offset:y_offset+loz_height, current_x:current_x+loz_width] = roi
    
    out.write(frame)
    print(f"Processing frame {frame_num + 1}/{TOTAL_FRAMES}")

out.release()
print("Animation complete!")
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Processing frame 1/90
# Processing frame 2/90
# Processing frame 3/90
# Processing frame 4/90
# Processing frame 5/90
# Processing frame 6/90
# Processing frame 7/90
# Processing frame 8/90
# Processing frame 9/90
# Processing frame 10/90
# Processing frame 11/90
# Processing frame 12/90
# Processing frame 13/90
# Processing frame 14/90
# Processing frame 15/90
# Processing frame 16/90
# Processing frame 17/90
# Processing frame 18/90
# Processing frame 19/90
# Processing frame 20/90
# Processing frame 21/90
# Processing frame 22/90
# Processing frame 23/90
# Processing frame 24/90
# Processing frame 25/90
# Processing frame 26/90
# Processing frame 27/90
# Processing frame 28/90
# Processing frame 29/90
# Processing frame 30/90
# Processing frame 31/90
# Processing frame 32/90
# Processing frame 33/90
# Processing frame 34/90
# Processing frame 35/90
# Processing frame 36/90
# Processing frame 37/90
# Processing frame 38/90
# Processing frame 39/90
# Processing frame 40/90
# Processing frame 41/90
# Processing frame 42/90
# Processing frame 43/90
# Processing frame 44/90
# Processing frame 45/90
# Processing frame 46/90
# Processing frame 47/90
# Processing frame 48/90
# Processing frame 49/90
# Processing frame 50/90
# Processing frame 51/90
# Processing frame 52/90
# Processing frame 53/90
# Processing frame 54/90
# Processing frame 55/90
# Processing frame 56/90
# Processing frame 57/90
# Processing frame 58/90
# Processing frame 59/90
# Processing frame 60/90
# Processing frame 61/90
# Processing frame 62/90
# Processing frame 63/90
# Processing frame 64/90
# Processing frame 65/90
# Processing frame 66/90
# Processing frame 67/90
# Processing frame 68/90
# Processing frame 69/90
# Processing frame 70/90
# Processing frame 71/90
# Processing frame 72/90
# Processing frame 73/90
# Processing frame 74/90
# Processing frame 75/90
# Processing frame 76/90
# Processing frame 77/90
# Processing frame 78/90
# Processing frame 79/90
# Processing frame 80/90
# Processing frame 81/90
# Processing frame 82/90
# Processing frame 83/90
# Processing frame 84/90
# Processing frame 85/90
# Processing frame 86/90
# Processing frame 87/90
# Processing frame 88/90
# Processing frame 89/90
# Processing frame 90/90
# Animation complete!

# %%
output_path = "archive/data/imgs/synth__/lozenge_circle.mp4"

# Constants
FPS = 30
DURATION = 30  # 30 seconds
TOTAL_FRAMES = FPS * DURATION
RADIUS = 200    # Radius of circular motion

# Get reference dimensions
reference_img = cv2.imread(reference_img_path)
bg_height, bg_width = reference_img.shape[:2]

# Create white background
background = np.full((bg_height, bg_width, 3), 255, dtype=np.uint8)

# Load and scale lozenge
lozenge_files = [f for f in os.listdir(lozenge_dir) if f.endswith(('.png', '.PNG'))]
selected_lozenge_file = random.choice(lozenge_files)
lozenge = cv2.imread(os.path.join(lozenge_dir, selected_lozenge_file), cv2.IMREAD_UNCHANGED)

REFERENCE_LOZENGE_SIZE = (331, 364)
scaled_lozenge = cv2.resize(lozenge, REFERENCE_LOZENGE_SIZE)
loz_height, loz_width = scaled_lozenge.shape[:2]

# Setup video writer
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter(output_path, fourcc, FPS, (bg_width, bg_height))

# Calculate center point of the background
center_x = bg_width // 2
center_y = bg_height // 2

for frame_num in range(TOTAL_FRAMES):
    frame = background.copy()
    
    # Calculate progress (0 to 2π for a full circle)
    progress = (frame_num / TOTAL_FRAMES) * 4 * np.pi  # 2 full rotations
    
    # Determine direction based on time
    if frame_num < TOTAL_FRAMES // 2:
        # First half: clockwise
        angle = progress
    else:
        # Second half: counterclockwise
        angle = 4 * np.pi - (progress - 2 * np.pi)
    
    # Calculate position on circle
    current_x = int(center_x + RADIUS * np.cos(angle))
    current_y = int(center_y + RADIUS * np.sin(angle))
    
    # Adjust for lozenge size to keep center point on the circle
    x_offset = current_x - (loz_width // 2)
    y_offset = current_y - (loz_height // 2)
    
    # Ensure lozenge stays within frame
    x_offset = max(0, min(x_offset, bg_width - loz_width))
    y_offset = max(0, min(y_offset, bg_height - loz_height))
    
    # Blend lozenge
    loz = scaled_lozenge.astype(np.float32) / 255.0
    alpha_channel = loz[:, :, 3]
    rgb_loz = loz[:, :, :3]
    
    roi = frame[y_offset:y_offset+loz_height, 
                x_offset:x_offset+loz_width].astype(np.float32) / 255.0
    
    for c in range(3):
        roi[:, :, c] = roi[:, :, c] * (1 - alpha_channel) + rgb_loz[:, :, c] * alpha_channel
    
    roi = (roi * 255).astype(np.uint8)
    frame[y_offset:y_offset+loz_height, x_offset:x_offset+loz_width] = roi
    
    out.write(frame)
    if frame_num % FPS == 0:  # Print progress every second
        print(f"Processing second {frame_num // FPS + 1}/{DURATION}")

out.release()
print("Animation complete!")
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Processing second 1/180
# Processing second 2/180
# Processing second 3/180
# Processing second 4/180
# Processing second 5/180
# Processing second 6/180
# Processing second 7/180
# Processing second 8/180
# Processing second 9/180
# Processing second 10/180
# Processing second 11/180
# Processing second 12/180
# Processing second 13/180
# Processing second 14/180
# Processing second 15/180
# Processing second 16/180
# Processing second 17/180
# Processing second 18/180
# Processing second 19/180
# Processing second 20/180
# Processing second 21/180
# Processing second 22/180
# Processing second 23/180
# Processing second 24/180
# Processing second 25/180
# Processing second 26/180
# Processing second 27/180
# Processing second 28/180
# Processing second 29/180
# Processing second 30/180
# Processing second 31/180
# Processing second 32/180
# Processing second 33/180
# Processing second 34/180
# Processing second 35/180
# Processing second 36/180
# Processing second 37/180
# Processing second 38/180
# Processing second 39/180
# Processing second 40/180
# Processing second 41/180
# Processing second 42/180
# Processing second 43/180
# Processing second 44/180
# Processing second 45/180
# Processing second 46/180
# Processing second 47/180
# Processing second 48/180
# Processing second 49/180
# Processing second 50/180
# Processing second 51/180
# Processing second 52/180
# Processing second 53/180
# Processing second 54/180
# Processing second 55/180
# Processing second 56/180
# Processing second 57/180
# Processing second 58/180
# Processing second 59/180
# Processing second 60/180
# Processing second 61/180
# Processing second 62/180
# Processing second 63/180
# Processing second 64/180
# Processing second 65/180
# Processing second 66/180
# Processing second 67/180
# Processing second 68/180
# Processing second 69/180
# Processing second 70/180
# Processing second 71/180
# Processing second 72/180
# Processing second 73/180
# Processing second 74/180
# Processing second 75/180
# Processing second 76/180
# Processing second 77/180
# Processing second 78/180
# Processing second 79/180
# Processing second 80/180
# Processing second 81/180
# Processing second 82/180
# Processing second 83/180
# Processing second 84/180
# Processing second 85/180
# Processing second 86/180
# Processing second 87/180
# Processing second 88/180
# Processing second 89/180
# Processing second 90/180
# Processing second 91/180
# Processing second 92/180
# Processing second 93/180
# Processing second 94/180
# Processing second 95/180
# Processing second 96/180
# Processing second 97/180
# Processing second 98/180
# Processing second 99/180
# Processing second 100/180
# Processing second 101/180
# Processing second 102/180
# Processing second 103/180
# Processing second 104/180
# Processing second 105/180
# Processing second 106/180
# Processing second 107/180
# Processing second 108/180
# Processing second 109/180
# Processing second 110/180
# Processing second 111/180
# Processing second 112/180
# Processing second 113/180
# Processing second 114/180
# Processing second 115/180
# Processing second 116/180
# Processing second 117/180
# Processing second 118/180
# Processing second 119/180
# Processing second 120/180
# Processing second 121/180
# Processing second 122/180
# Processing second 123/180
# Processing second 124/180
# Processing second 125/180
# Processing second 126/180
# Processing second 127/180
# Processing second 128/180
# Processing second 129/180
# Processing second 130/180
# Processing second 131/180
# Processing second 132/180
# Processing second 133/180
# Processing second 134/180
# Processing second 135/180
# Processing second 136/180
# Processing second 137/180
# Processing second 138/180
# Processing second 139/180
# Processing second 140/180
# Processing second 141/180
# Processing second 142/180
# Processing second 143/180
# Processing second 144/180
# Processing second 145/180
# Processing second 146/180
# Processing second 147/180
# Processing second 148/180
# Processing second 149/180
# Processing second 150/180
# Processing second 151/180
# Processing second 152/180
# Processing second 153/180
# Processing second 154/180
# Processing second 155/180
# Processing second 156/180
# Processing second 157/180
# Processing second 158/180
# Processing second 159/180
# Processing second 160/180
# Processing second 161/180
# Processing second 162/180
# Processing second 163/180
# Processing second 164/180
# Processing second 165/180
# Processing second 166/180
# Processing second 167/180
# Processing second 168/180
# Processing second 169/180
# Processing second 170/180
# Processing second 171/180
# Processing second 172/180
# Processing second 173/180
# Processing second 174/180
# Processing second 175/180
# Processing second 176/180
# Processing second 177/180
# Processing second 178/180
# Processing second 179/180
# Processing second 180/180
# Animation complete!
